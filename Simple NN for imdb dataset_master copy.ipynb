# %% [markdown]
# # Basic of simple fully connected neural network

# %% [markdown]
# 1. Introduction
#
#    * An artificial neural network (ANN) is a network inspired by biological neural networks which are used to estimate or approximate functions that can depend on a large number of inputs that are generally unknown
#    * A fully-connected neural network (NN) contains stacked nodes connected from the input layer -> hidden layers -> output layer
#    * A node in a neural network is built from Weights and Activation function
#    * During the early days, ANN containing a single node is called the preceptron
#
# <img src="data/images/Perceptron.png" width="45%">

# %% [markdown]
#    * A Perceptron Network can be designed to have multiple layers, leading to the Multi-Layer Perceptron (aka `MLP`)
#
# <img src="data/images/MLP.png" width="45%">

# %%
# import relevant libraries
import numpy as np
import pandas as pd
from keras.datasets import imdb # see more information from https://keras.io/datasets/
# Dataset of 25,000 movies reviews from IMDB, labeled by sentiment (positive/negative). 
# Reviews have been preprocessed, and each review is encoded as a sequence of word indexes 
# (integers). For convenience, words are indexed by overall frequency in the dataset, 
# so that for instance the integer "3" encodes the 3rd most frequent word in the data. 
# This allows for quick filtering operations 
# such as: "only consider the top 10,000 most common words, but eliminate the top 20 most 
# common words
from keras.preprocessing.text import Tokenizer 
from sklearn.model_selection import train_test_split
from keras import models
from keras import layers
# Out:
# C:\Users\Alvin\Anaconda3\lib\site-packages\h5py\__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %%
# view dataset
no_features = 1000
(x_train,y_train),(x_test,y_test) = imdb.load_data(num_words = no_features) 
# num_words refers to the maximum number of words to keep, based on word frequency. 
# Only the most common num_words will be kept
new_table = pd.DataFrame()
new_table['x-train data'] = x_train
new_table['y-train data'] = y_train
new_table['x-test data'] = x_test
new_table['y-test data'] = y_test
new_table.head()
# Out:
#                                         x-train data  y-train data  \
# 0  [1, 14, 22, 16, 43, 530, 973, 2, 2, 65, 458, 2...             1
# 1  [1, 194, 2, 194, 2, 78, 228, 5, 6, 2, 2, 2, 13...             0
# 2  [1, 14, 47, 8, 30, 31, 7, 4, 249, 108, 7, 4, 2...             0
# 3  [1, 4, 2, 2, 33, 2, 4, 2, 432, 111, 153, 103, ...             1
# 4  [1, 249, 2, 7, 61, 113, 10, 10, 13, 2, 14, 20,...             0
#
#                                          x-test data  y-test data
# 0  [1, 591, 202, 14, 31, 6, 717, 10, 10, 2, 2, 5,...            0
# 1  [1, 14, 22, 2, 6, 176, 7, 2, 88, 12, 2, 23, 2,...            1
# 2  [1, 111, 748, 2, 2, 2, 2, 4, 87, 2, 2, 7, 31, ...            1
# 3  [1, 13, 2, 119, 14, 552, 7, 20, 190, 14, 58, 1...            0
# 4  [1, 40, 49, 85, 84, 2, 146, 6, 783, 254, 2, 33...            1

# %% [markdown]
# 2. Building of neural network model
#
#     * To create a two-layer neural network (NN). Note that when counting layers we don't include the input layer as it does not have any parameters to learn.
#
#     * Each layer is "dense" which is also called as fully connected, i.e. all the units in the previous layer are connected to all the neurals in the next layer
#
#     Important parameters to be concerned:
#
#     * units -> number of nodes
#
#     * activation -> activation function
#
#     * input_shape -> shape of input feature data

# %%
# initiate neural network
nn_model = models.Sequential()
nn_model.add(layers.Dense(units=16, activation="relu", input_shape=(1000,)))
nn_model.add(layers.Dense(units=16, activation='relu'))
nn_model.add(layers.Dense(units=1, activation='sigmoid'))

# %% [markdown]
# 3. Compilation of neural network model
#
#     * To create a two-layer neural network (NN). Note that when counting layers we don't include the input layer as it does not have any parameters to learn.
#
#     * Each layer is "dense" which is also called as fully connected, i.e. all the units in the previous layer are connected to all the neurals in the next layer
#
#     Important parameters to be concerned:
#
#     * units -> number of nodes
#
#     * activation -> activation function
#
#     * input_shape -> shape of input feature data

# %%
# model compilation
nn_model.compile(loss='binary_crossentropy',optimizer='rmsprop',metrics=['accuracy'])
nn_model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_1 (Dense)              (None, 16)                16016
# _________________________________________________________________
# dense_2 (Dense)              (None, 16)                272
# _________________________________________________________________
# dense_3 (Dense)              (None, 1)                 17
# =================================================================
# Total params: 16,305
# Trainable params: 16,305
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# 4. Training a binary classifier neural network
#
#     Step 1: Decide on the number of input features
#
#     Step 2: Setting up of training and validation datasets
#
#     Use of tokenizer as the text preprocessing function. For more information, see https://keras.io/preprocessing/text/
#
#     Step 3: Model training

# %%
# fitting ANN model
tokenizer = Tokenizer(num_words = no_features)
train_features = tokenizer.sequences_to_matrix(x_train,mode='binary')
test_features = tokenizer.sequences_to_matrix(x_test,mode='binary')
# print(train_features.shape,test_features.shape)

model_history = nn_model.fit(train_features,
                            y_train,
                            epochs = 100,
                            verbose = 2,
                            batch_size = 100,
                            validation_data = (test_features,y_test))
# Out:
# Train on 25000 samples, validate on 25000 samples
# Epoch 1/100
#  - 2s - loss: 0.4159 - acc: 0.8135 - val_loss: 0.3346 - val_acc: 0.8588
# Epoch 2/100
#  - 1s - loss: 0.3247 - acc: 0.8640 - val_loss: 0.3289 - val_acc: 0.8605
# Epoch 3/100
#  - 1s - loss: 0.3151 - acc: 0.8667 - val_loss: 0.3304 - val_acc: 0.8597
# Epoch 4/100
#  - 1s - loss: 0.3067 - acc: 0.8724 - val_loss: 0.3345 - val_acc: 0.8575
# Epoch 5/100
#  - 1s - loss: 0.2998 - acc: 0.8739 - val_loss: 0.3267 - val_acc: 0.8590
# Epoch 6/100
#  - 1s - loss: 0.2908 - acc: 0.8790 - val_loss: 0.3321 - val_acc: 0.8562
# Epoch 7/100
#  - 1s - loss: 0.2812 - acc: 0.8822 - val_loss: 0.3304 - val_acc: 0.8575
# Epoch 8/100
#  - 1s - loss: 0.2707 - acc: 0.8882 - val_loss: 0.3303 - val_acc: 0.8584
# Epoch 9/100
#  - 1s - loss: 0.2587 - acc: 0.8907 - val_loss: 0.3399 - val_acc: 0.8554
# Epoch 10/100
#  - 1s - loss: 0.2466 - acc: 0.8970 - val_loss: 0.3413 - val_acc: 0.8564
# Epoch 11/100
#  - 1s - loss: 0.2343 - acc: 0.9034 - val_loss: 0.3576 - val_acc: 0.8539
# Epoch 12/100
#  - 1s - loss: 0.2217 - acc: 0.9116 - val_loss: 0.3580 - val_acc: 0.8526
# Epoch 13/100
#  - 1s - loss: 0.2093 - acc: 0.9164 - val_loss: 0.3779 - val_acc: 0.8496
# Epoch 14/100
#  - 1s - loss: 0.1961 - acc: 0.9235 - val_loss: 0.3835 - val_acc: 0.8464
# Epoch 15/100
#  - 1s - loss: 0.1838 - acc: 0.9293 - val_loss: 0.4302 - val_acc: 0.8450
# Epoch 16/100
#  - 1s - loss: 0.1725 - acc: 0.9346 - val_loss: 0.4375 - val_acc: 0.8424
# Epoch 17/100
#  - 1s - loss: 0.1605 - acc: 0.9420 - val_loss: 0.4547 - val_acc: 0.8418
# Epoch 18/100
#  - 1s - loss: 0.1496 - acc: 0.9458 - val_loss: 0.4782 - val_acc: 0.8402
# Epoch 19/100
#  - 1s - loss: 0.1399 - acc: 0.9503 - val_loss: 0.4936 - val_acc: 0.8368
# Epoch 20/100
#  - 1s - loss: 0.1311 - acc: 0.9532 - val_loss: 0.5230 - val_acc: 0.8366
# Epoch 21/100
#  - 1s - loss: 0.1207 - acc: 0.9586 - val_loss: 0.5626 - val_acc: 0.8342
# Epoch 22/100
#  - 1s - loss: 0.1124 - acc: 0.9620 - val_loss: 0.5948 - val_acc: 0.8336
# Epoch 23/100
#  - 1s - loss: 0.1027 - acc: 0.9665 - val_loss: 0.6225 - val_acc: 0.8338
# Epoch 24/100
#  - 1s - loss: 0.0946 - acc: 0.9690 - val_loss: 0.6639 - val_acc: 0.8315
# Epoch 25/100
#  - 1s - loss: 0.0876 - acc: 0.9722 - val_loss: 0.6748 - val_acc: 0.8300
# Epoch 26/100
#  - 1s - loss: 0.0809 - acc: 0.9757 - val_loss: 0.7354 - val_acc: 0.8289
# Epoch 27/100
#  - 1s - loss: 0.0737 - acc: 0.9779 - val_loss: 0.7746 - val_acc: 0.8275
# Epoch 28/100
#  - 1s - loss: 0.0673 - acc: 0.9792 - val_loss: 0.7903 - val_acc: 0.8285
# Epoch 29/100
#  - 1s - loss: 0.0610 - acc: 0.9831 - val_loss: 0.8772 - val_acc: 0.8265
# Epoch 30/100
#  - 1s - loss: 0.0569 - acc: 0.9840 - val_loss: 0.8518 - val_acc: 0.8259
# Epoch 31/100
#  - 1s - loss: 0.0507 - acc: 0.9860 - val_loss: 0.8923 - val_acc: 0.8247
# Epoch 32/100
#  - 1s - loss: 0.0462 - acc: 0.9874 - val_loss: 0.9237 - val_acc: 0.8246
# Epoch 33/100
#  - 1s - loss: 0.0425 - acc: 0.9890 - val_loss: 0.9529 - val_acc: 0.8232
# Epoch 34/100
#  - 1s - loss: 0.0390 - acc: 0.9898 - val_loss: 1.0349 - val_acc: 0.8223
# Epoch 35/100
#  - 1s - loss: 0.0356 - acc: 0.9909 - val_loss: 1.0405 - val_acc: 0.8235
# Epoch 36/100
#  - 1s - loss: 0.0318 - acc: 0.9919 - val_loss: 1.0671 - val_acc: 0.8216
# Epoch 37/100
#  - 1s - loss: 0.0282 - acc: 0.9937 - val_loss: 1.1083 - val_acc: 0.8239
# Epoch 38/100
#  - 1s - loss: 0.0269 - acc: 0.9934 - val_loss: 1.2054 - val_acc: 0.8156
# Epoch 39/100
#  - 1s - loss: 0.0248 - acc: 0.9945 - val_loss: 1.1597 - val_acc: 0.8217
# Epoch 40/100
#  - 1s - loss: 0.0210 - acc: 0.9954 - val_loss: 1.2089 - val_acc: 0.8200
# Epoch 41/100
#  - 1s - loss: 0.0198 - acc: 0.9954 - val_loss: 1.2073 - val_acc: 0.8207
# Epoch 42/100
#  - 1s - loss: 0.0190 - acc: 0.9960 - val_loss: 1.3234 - val_acc: 0.8157
# Epoch 43/100
#  - 1s - loss: 0.0162 - acc: 0.9967 - val_loss: 1.3104 - val_acc: 0.8180
# Epoch 44/100
#  - 1s - loss: 0.0148 - acc: 0.9967 - val_loss: 1.3148 - val_acc: 0.8208
# Epoch 45/100
#  - 1s - loss: 0.0136 - acc: 0.9976 - val_loss: 1.3582 - val_acc: 0.8172
# Epoch 46/100
#  - 1s - loss: 0.0133 - acc: 0.9970 - val_loss: 1.3453 - val_acc: 0.8166
# Epoch 47/100
#  - 1s - loss: 0.0121 - acc: 0.9974 - val_loss: 1.3742 - val_acc: 0.8189
# Epoch 48/100
#  - 1s - loss: 0.0119 - acc: 0.9973 - val_loss: 1.3934 - val_acc: 0.8174
# Epoch 49/100
#  - 1s - loss: 0.0104 - acc: 0.9976 - val_loss: 1.4046 - val_acc: 0.8164
# Epoch 50/100
#  - 1s - loss: 0.0093 - acc: 0.9979 - val_loss: 1.4345 - val_acc: 0.8178
# Epoch 51/100
#  - 1s - loss: 0.0097 - acc: 0.9981 - val_loss: 1.4565 - val_acc: 0.8171
# Epoch 52/100
#  - 1s - loss: 0.0088 - acc: 0.9981 - val_loss: 1.4890 - val_acc: 0.8154
# Epoch 53/100
#  - 1s - loss: 0.0095 - acc: 0.9976 - val_loss: 1.4951 - val_acc: 0.8172
# Epoch 54/100
#  - 1s - loss: 0.0076 - acc: 0.9986 - val_loss: 1.5144 - val_acc: 0.8172
# Epoch 55/100
#  - 1s - loss: 0.0068 - acc: 0.9986 - val_loss: 1.5828 - val_acc: 0.8076
# Epoch 56/100
#  - 1s - loss: 0.0072 - acc: 0.9985 - val_loss: 1.5424 - val_acc: 0.8167
# Epoch 57/100
#  - 1s - loss: 0.0071 - acc: 0.9986 - val_loss: 1.5590 - val_acc: 0.8169
# Epoch 58/100
#  - 1s - loss: 0.0048 - acc: 0.9990 - val_loss: 1.5863 - val_acc: 0.8156
# Epoch 59/100
#  - 1s - loss: 0.0045 - acc: 0.9990 - val_loss: 1.5978 - val_acc: 0.8129
# Epoch 60/100
#  - 1s - loss: 0.0050 - acc: 0.9990 - val_loss: 1.6231 - val_acc: 0.8128
# Epoch 61/100
#  - 1s - loss: 0.0069 - acc: 0.9987 - val_loss: 1.6521 - val_acc: 0.8138
# Epoch 62/100
#  - 1s - loss: 0.0060 - acc: 0.9984 - val_loss: 1.6521 - val_acc: 0.8134
# Epoch 63/100
#  - 1s - loss: 0.0034 - acc: 0.9994 - val_loss: 1.6708 - val_acc: 0.8132
# Epoch 64/100
#  - 1s - loss: 0.0052 - acc: 0.9988 - val_loss: 1.6818 - val_acc: 0.8146
# Epoch 65/100
#  - 1s - loss: 0.0048 - acc: 0.9986 - val_loss: 1.6787 - val_acc: 0.8132
# Epoch 66/100
#  - 1s - loss: 0.0042 - acc: 0.9989 - val_loss: 1.6883 - val_acc: 0.8133
# Epoch 67/100
#  - 1s - loss: 0.0041 - acc: 0.9989 - val_loss: 1.7570 - val_acc: 0.8100
# Epoch 68/100
#  - 1s - loss: 0.0055 - acc: 0.9987 - val_loss: 1.7014 - val_acc: 0.8141
# Epoch 69/100
#  - 1s - loss: 0.0045 - acc: 0.9992 - val_loss: 1.7303 - val_acc: 0.8141
# Epoch 70/100
#  - 1s - loss: 0.0052 - acc: 0.9990 - val_loss: 1.7321 - val_acc: 0.8140
# Epoch 71/100
#  - 1s - loss: 0.0031 - acc: 0.9994 - val_loss: 1.7510 - val_acc: 0.8123
# Epoch 72/100
#  - 1s - loss: 0.0045 - acc: 0.9988 - val_loss: 1.7575 - val_acc: 0.8122
# Epoch 73/100
#  - 1s - loss: 0.0047 - acc: 0.9989 - val_loss: 1.7799 - val_acc: 0.8109
# Epoch 74/100
#  - 1s - loss: 0.0052 - acc: 0.9986 - val_loss: 1.7797 - val_acc: 0.8106
# Epoch 75/100
#  - 1s - loss: 0.0049 - acc: 0.9989 - val_loss: 1.7871 - val_acc: 0.8128
# Epoch 76/100
#  - 1s - loss: 0.0027 - acc: 0.9993 - val_loss: 1.8027 - val_acc: 0.8137
# Epoch 77/100
#  - 1s - loss: 0.0031 - acc: 0.9992 - val_loss: 1.8145 - val_acc: 0.8128
# Epoch 78/100
#  - 1s - loss: 0.0024 - acc: 0.9994 - val_loss: 1.8270 - val_acc: 0.8128
# Epoch 79/100
#  - 1s - loss: 0.0037 - acc: 0.9990 - val_loss: 1.8289 - val_acc: 0.8126
# Epoch 80/100
#  - 1s - loss: 0.0014 - acc: 0.9998 - val_loss: 1.8397 - val_acc: 0.8114
# Epoch 81/100
#  - 1s - loss: 0.0034 - acc: 0.9994 - val_loss: 1.8661 - val_acc: 0.8116
# Epoch 82/100
#  - 1s - loss: 0.0049 - acc: 0.9986 - val_loss: 1.8531 - val_acc: 0.8117
# Epoch 83/100
#  - 1s - loss: 0.0017 - acc: 0.9994 - val_loss: 1.8623 - val_acc: 0.8124
# Epoch 84/100
#  - 1s - loss: 0.0042 - acc: 0.9990 - val_loss: 1.8747 - val_acc: 0.8119
# Epoch 85/100
#  - 1s - loss: 0.0042 - acc: 0.9989 - val_loss: 1.9064 - val_acc: 0.8082
# Epoch 86/100
#  - 1s - loss: 0.0028 - acc: 0.9994 - val_loss: 1.8774 - val_acc: 0.8113
# Epoch 87/100
#  - 1s - loss: 0.0024 - acc: 0.9996 - val_loss: 1.9003 - val_acc: 0.8116
# Epoch 88/100
#  - 1s - loss: 0.0014 - acc: 0.9997 - val_loss: 1.9053 - val_acc: 0.8110
# Epoch 89/100
#  - 1s - loss: 0.0018 - acc: 0.9994 - val_loss: 1.9322 - val_acc: 0.8087
# Epoch 90/100
#  - 1s - loss: 0.0028 - acc: 0.9993 - val_loss: 1.9759 - val_acc: 0.8056
# Epoch 91/100
#  - 1s - loss: 0.0016 - acc: 0.9995 - val_loss: 1.9485 - val_acc: 0.8095
# Epoch 92/100
#  - 1s - loss: 0.0019 - acc: 0.9995 - val_loss: 1.9417 - val_acc: 0.8099
# Epoch 93/100
#  - 1s - loss: 0.0023 - acc: 0.9994 - val_loss: 1.9696 - val_acc: 0.8069
# Epoch 94/100
#  - 1s - loss: 0.0014 - acc: 0.9997 - val_loss: 1.9631 - val_acc: 0.8099
# Epoch 95/100
#  - 1s - loss: 0.0016 - acc: 0.9996 - val_loss: 1.9906 - val_acc: 0.8090
# Epoch 96/100
#  - 1s - loss: 0.0012 - acc: 0.9996 - val_loss: 2.0158 - val_acc: 0.8061
# Epoch 97/100
#  - 1s - loss: 0.0019 - acc: 0.9994 - val_loss: 1.9904 - val_acc: 0.8085
# Epoch 98/100
#  - 1s - loss: 0.0021 - acc: 0.9995 - val_loss: 2.0079 - val_acc: 0.8074
# Epoch 99/100
#  - 1s - loss: 0.0016 - acc: 0.9994 - val_loss: 1.9984 - val_acc: 0.8051
# Epoch 100/100
#  - 1s - loss: 0.0012 - acc: 0.9995 - val_loss: 2.0099 - val_acc: 0.8060
